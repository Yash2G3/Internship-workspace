# %% [markdown]
# # Visualisation of data in pandas lib

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
df1=pd.read_csv('df1',index_col=0)
# importing a data file and setting the first column as index column

# %%
df2=pd.read_csv('df2')

# %% [markdown]
# ## Creating plots directly from data columns

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1['A'].hist(bins=20)
# creating a histogram from the first data column
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Note: always add bins when directly visualising data

# %% [markdown]
# # fundametnal plots inside pandas

# %% [markdown]
# ### step1 : making a plot
#
# syntax1: df_name[  'Column name'  ].plot(  kind=' th kind of graph you wanna plot',   bins= num value   )
#
# syntax2: df_name[  'COlumn name'  ]. plot.graph_type(bins= num value)

# %% [markdown]
# # 1. Histplot/Histograms

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1['A'].plot(kind='hist',bins=30)
# using syntax 1
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot.hist()
# using syntax 2
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # 2. Area Plot

# %% [markdown]
# it used to plot the values by plotting a line joining them and lighting up the area underneath it
#
# each column to be plotted requires all values to be either positve or negative

# %%
df1.plot.area()
# error occurs as column A has both positive and neative points
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 df1.plot.area()
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:1529, in PlotAccessor.area(self, x, y, **kwargs)
#    1458 def area(self, x=None, y=None, **kwargs):
#    1459     """
#    1460     Draw a stacked area plot.
#    1461
#    (...)
#    1527         >>> ax = df.plot.area(x='day')
#    1528     """
# -> 1529     return self(kind="area", x=x, y=y, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
# ...

# %%
df2.plot.area()
# ooo la laaaa!!!
# each line of color reprsents each column
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3.Barplots
#
# plots rows(x) vs column(y)
#
# rows are categorical data
#
# and their values from columns are printed as bars

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# to stack all results in each column on top of each other
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 4. Lineplots
#
# syntax: df_name/column.plot.line(x= { x axis data }, y= { y axis data}   )
#
# other attributes:
#
# figsize
#
# line width

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.line(use_index=True, y='B',figsize=(15,5),lw=1)
# to set index column as x axis use the command set_index=True
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Tip: to use index column as x axis use the command use_index=True

# %% [markdown]
# # Scatter Plot

# %%
df1.plot.scatter(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %% [markdown]
# # Adding the third axis in scatterplots
#
# on basis of:
#
# 1.color
#
# 2.size
#
# you can also add a third axis of color in the scatterplot
#
# syntax: df_name.plot.scatter(x='smntn' ,y='smthn', c="this id where you put in the third axis on basis of color")

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.scatter(x='a', y='b', c='d',cmap='Blues')
# see how the third axis of d is used as color
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# # Box plots

# %%
df2.col['a','b]'.plot.box(cmap='coolwarm)
# Out:
#   Input In [28]
#     df2.col['a','b]'.plot.box(cmap='coolwarm)
#                                              ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# # Hexgonal Bin Plot
#
# alternative of scatter plot
#
# requirements:
#
# data frame(outside)
#
# x axis data
#
# y axis data
#
# other attribures:
#
# grindsize: num value➡️as grind size dec size of each hexagon incre
# ,
# cmap: for color
#
#     `Syntax: df_name.plot.hexbin( x='smthn', y='smthn', grindsize= num value  )

# %%
ntt=pd.DataFrame(np.random.randn(100,2),columns=['a','b'])

# %%
ntt.head()
# Out:
#           a         b
# 0 -1.576367  0.475137
# 1  0.851321 -0.400386
# 2  0.473606  0.913744
# 3  0.119541  1.662537
# 4 -0.794532 -0.004438

# %%
ntt.plot.hexbin(x='a',y='b',gridsize=20)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# # 5. KDE plots

# %% [markdown]
# df_name/column.plot.kdf/density()

# %%
df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
