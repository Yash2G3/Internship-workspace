# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# reading sachin's data
df1=pd.read_csv('SACHIN_BATTING_CARD.csv')

# %%
df1.head()
# Out:
#    Ball  Ball_no       Striker Non_striker      Bowler  Runs_by_batsman  \
# 0     1      0.3  SR Tendulkar    V Sehwag    DW Steyn                0
# 1     2      0.4  SR Tendulkar    V Sehwag    DW Steyn                0
# 2     3      0.5  SR Tendulkar    V Sehwag    DW Steyn                0
# 3     4      0.6  SR Tendulkar    V Sehwag    DW Steyn                0
# 4     5      1.3  SR Tendulkar    V Sehwag  WD Parnell                4
#
#    Total_runs  Strike_rate  Extras  Wides  No_balls  Byes  Leg_byes
# 0           0          0.0       0    NaN       NaN   NaN       NaN
# 1           0          0.0       0    NaN       NaN   NaN       NaN
# 2           0          0.0       0    NaN       NaN   NaN       NaN
# 3           0          0.0       0    NaN       NaN   NaN       NaN
# 4           4         80.0       0    NaN       NaN   NaN       NaN

# %%
df2=pd.read_csv('COVENTORY_BALL.csv')
df2.head()
# Out:
#    Ball  Ball_No      Striker  Non_striker         Bowler  Runs_by_batsman  \
# 0     1      1.4  CK Coventry  H Masakadza  Mahbubul Alam                0
# 1     2      1.5  CK Coventry  H Masakadza  Mahbubul Alam                0
# 2     3      1.6  CK Coventry  H Masakadza  Mahbubul Alam                0
# 3     4      3.1  CK Coventry  H Masakadza  Mahbubul Alam                0
# 4     5      3.2  CK Coventry  H Masakadza  Mahbubul Alam                1
#
#    Total_runs  Strike_rate  Extras  Wides  No_balls  Byes  Leg_byes
# 0           0          0.0       0    NaN       NaN   NaN       NaN
# 1           0          0.0       0    NaN       NaN   NaN       NaN
# 2           0          0.0       0    NaN       NaN   NaN       NaN
# 3           0          0.0       0    NaN       NaN   NaN       NaN
# 4           1         20.0       0    NaN       NaN   NaN       NaN

# %%
# reading ross taylor's data
df3=pd.read_csv('taylor_181.csv')

# %%
df3.head()
# Out:
#    Ball  Ball_No      Striker    Non_striker   Bowler  Runs_by_batsman  \
# 0     1      3.1  LRPL Taylor  KS Williamson  MA Wood                0
# 1     2      3.2  LRPL Taylor  KS Williamson  MA Wood                0
# 2     3      3.3  LRPL Taylor  KS Williamson  MA Wood                0
# 3     4      3.4  LRPL Taylor  KS Williamson  MA Wood                0
# 4     5      3.5  LRPL Taylor  KS Williamson  MA Wood                0
#
#    Total_runs  Strike_rate  Extras  Wides  No_balls  Byes  Leg_byes  Penalty  \
# 0           0          0.0       0    NaN       NaN   NaN       NaN      NaN
# 1           0          0.0       0    NaN       NaN   NaN       NaN      NaN
# 2           0          0.0       0    NaN       NaN   NaN       NaN      NaN
# 3           0          0.0       0    NaN       NaN   NaN       NaN      NaN
# 4           0          0.0       0    NaN       NaN   NaN       NaN      NaN
#
#    Type_of_wicket  Player_dismissed
# 0             NaN               NaN
# ...

# %%
tickers=['Sachin','Coventory','Taylor']

# %%
df4=pd.concat([df1,df2,df3],axis=1,keys=tickers)
df4.columns.names=['Player_ticker','Details']
df4.head()
# Out:
# Player_ticker Sachin                                                \
# Details         Ball Ball_no       Striker Non_striker      Bowler
# 0                1.0     0.3  SR Tendulkar    V Sehwag    DW Steyn
# 1                2.0     0.4  SR Tendulkar    V Sehwag    DW Steyn
# 2                3.0     0.5  SR Tendulkar    V Sehwag    DW Steyn
# 3                4.0     0.6  SR Tendulkar    V Sehwag    DW Steyn
# 4                5.0     1.3  SR Tendulkar    V Sehwag  WD Parnell
#
# Player_ticker                                                      ...  \
# Details       Runs_by_batsman Total_runs Strike_rate Extras Wides  ...
# 0                         0.0        0.0         0.0    0.0   NaN  ...
# 1                         0.0        0.0         0.0    0.0   NaN  ...
# 2                         0.0        0.0         0.0    0.0   NaN  ...
# 3                         0.0        0.0         0.0    0.0   NaN  ...
# ...

# %%
df4.info
# Out:
# <bound method DataFrame.info of Player_ticker Sachin                                                \
# Details         Ball Ball_no       Striker Non_striker      Bowler
# 0                1.0     0.3  SR Tendulkar    V Sehwag    DW Steyn
# 1                2.0     0.4  SR Tendulkar    V Sehwag    DW Steyn
# 2                3.0     0.5  SR Tendulkar    V Sehwag    DW Steyn
# 3                4.0     0.6  SR Tendulkar    V Sehwag    DW Steyn
# 4                5.0     1.3  SR Tendulkar    V Sehwag  WD Parnell
# ..               ...     ...           ...         ...         ...
# 151              NaN     NaN           NaN         NaN         NaN
# 152              NaN     NaN           NaN         NaN         NaN
# 153              NaN     NaN           NaN         NaN         NaN
# 154              NaN     NaN           NaN         NaN         NaN
# 155              NaN     NaN           NaN         NaN         NaN
#
# ...

# %%
for tick in tickers:
    df4[tick]['Strike_rate'].plot(label=tick,figsize=(20,10))
plt.legend()

# %%
import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df2['Total_runs']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#       ...
# 151    189
# 152    190
# 153    191
# 154    192
# 155    194
# Name: Total_runs, Length: 156, dtype: int64

# %%
plt.plot('Ball','Total_runs',data=df2)

# %%
plt.plot('Ball','Total_runs',data=df1)

# %%
plt.plot('Ball_No','Total_runs',data=df3)

# %%
for tick in tickers:
    df4[tick].plot(x='Total_runs',y='Ball',label=tick,figsize=(20,10))
plt.legend()

# %%
df4['Coventory']['Total_runs']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#       ...
# 151    189
# 152    190
# 153    191
# 154    192
# 155    194
# Name: Total_runs, Length: 156, dtype: int64

# %%
fig=plt.figure(figsize=(20,15))
ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(df1['Ball'],df1['Total_runs'],label='Sachin',color='green')

ax.plot(df3['Ball'],df3['Total_runs'],label='Taylor',color='blue')
plt.legend(loc=0)

# %%
fig=plt.figure(figsize=(20,15))
ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(df1['Ball'],df1['Strike_rate'],label='Sachin',color='green')

ax.plot(df3['Ball'],df3['Strike_rate'],label='Taylor',color='blue')
plt.legend(loc=0)

# %%
fig=plt.figure(figsize=(10,10))
sns.barplot(['Runs_by_batsman'],y=df1['Total_runs'])
# Out:
# C:\Users\yashv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [22], in <cell line: 2>()
#       1 fig=plt.figure(figsize=(10,10))
# ----> 2 sns.barplot(['Runs_by_batsman'],y=df1['Total_runs'])
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
# ...

# %%
fig=plt.figure(figsize=(10,10))
sns.heatmap(x=(df1['Ball_no'])/10,y=['Runs_by_batsman'],data=df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       1 fig=plt.figure(figsize=(10,10))
# ----> 2 sns.heatmap(x=(df1['Ball_no'])/10,y=['Runs_by_batsman'],data=df1)
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
fig=plt.figure(figsize=(10,10))
sns.distplot(df1['Runs_by_batsman'])
# Out:
# C:\Users\yashv\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='Runs_by_batsman', ylabel='Density'>

# %%
fig=plt.figure(figsize=(10,10))
sns.histplot(x=df1['Runs_by_batsman'])
# Out:
# <AxesSubplot:xlabel='Runs_by_batsman', ylabel='Count'>

# %%
fig=plt.figure(figsize=(10,10))
sns.histplot(x=df3['Bowler'],y=df3['Runs_by_batsman'])
# Out:
# <AxesSubplot:xlabel='Bowler', ylabel='Runs_by_batsman'>

# %%
fig=plt.figure(figsize=(15,10))
sns.barplot(x=df3['Bowler'],y=df3['Runs_by_batsman'])
# Out:
# <AxesSubplot:xlabel='Bowler', ylabel='Runs_by_batsman'>

# %%
fig=plt.figure(figsize=(15,10))
sns.boxplot(x=df2['Bowler'],y=df2['Total_runs'])
# Out:
# <AxesSubplot:xlabel='Bowler', ylabel='Total_runs'>

# %%
fig=plt.figure(figsize=(15,10))
sns.scatterplot(x=df2['Bowler'],y=df2['Runs_by_batsman'],data=df2,hue='Bowler')
# Out:
# <AxesSubplot:xlabel='Bowler', ylabel='Runs_by_batsman'>

# %%
fig=plt.figure(figsize=(15,10))
sns.boxplot(x=df1['Bowler'],y=df1['Runs_by_batsman'])
# Out:
# <AxesSubplot:xlabel='Bowler', ylabel='Runs_by_batsman'>

# %%
sns.pairplot(df1,hue='Bowler')

# %%
df2['Runs_by_batsman'].nunique()
# Out:
# 6

# %%
df1.plot.scatter(x=['Ball'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 df1.plot.scatter(x=['Ball'])
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
df1['Runs_by_batsman'].value_counts()
# Out:
# 1    56
# 0    50
# 4    25
# 2    13
# 6     3
# Name: Runs_by_batsman, dtype: int64

# %%
df3['Runs_by_batsman'].value_counts()
# Out:
# 1    65
# 0    53
# 4    17
# 6     6
# 2     6
# Name: Runs_by_batsman, dtype: int64

# %%
import math
math.floor(df1['Ball_no'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 2>()
#       1 import math
# ----> 2 math.floor(df1['Ball_no'])
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:191, in _coerce_method.<locals>.wrapper(self)
#     189 if len(self) == 1:
#     190     return converter(self.iloc[0])
# --> 191 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'float'>

# %%
arr2=arr.astype('int32')/10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 arr2=arr.astype('int32')/10
#
# NameError: name 'arr' is not defined

# %%
import numpy as np
np.ceil(arr2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 np.ceil(arr2)
#
# NameError: name 'arr2' is not defined

# %%
df1['Over']=np.ceil(arr2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 df1['Over']=np.ceil(arr2)
#
# NameError: name 'arr2' is not defined

# %%
df1
# Out:
#      Ball  Ball_no       Striker Non_striker         Bowler  Runs_by_batsman  \
# 0       1      0.3  SR Tendulkar    V Sehwag       DW Steyn                0
# 1       2      0.4  SR Tendulkar    V Sehwag       DW Steyn                0
# 2       3      0.5  SR Tendulkar    V Sehwag       DW Steyn                0
# 3       4      0.6  SR Tendulkar    V Sehwag       DW Steyn                0
# 4       5      1.3  SR Tendulkar    V Sehwag     WD Parnell                4
# ..    ...      ...           ...         ...            ...              ...
# 142   143     46.4  SR Tendulkar    MS Dhoni       DW Steyn                0
# 143   144     46.5  SR Tendulkar    MS Dhoni       DW Steyn                1
# 144   145     47.3  SR Tendulkar    MS Dhoni  CK Langeveldt                0
# 145   146     47.4  SR Tendulkar    MS Dhoni  CK Langeveldt                1
# 146   147     49.3  SR Tendulkar    MS Dhoni  CK Langeveldt                1
#
# ...

# %%
df3.head()
test=np.ceil(df3['Ball_No'])
df3['Over']=test

# %%
df3
# Out:
#      Ball  Ball_No      Striker    Non_striker     Bowler  Runs_by_batsman  \
# 0       1      3.1  LRPL Taylor  KS Williamson    MA Wood                0
# 1       2      3.2  LRPL Taylor  KS Williamson    MA Wood                0
# 2       3      3.3  LRPL Taylor  KS Williamson    MA Wood                0
# 3       4      3.4  LRPL Taylor  KS Williamson    MA Wood                0
# 4       5      3.5  LRPL Taylor  KS Williamson    MA Wood                0
# ..    ...      ...          ...            ...        ...              ...
# 142   143     47.5  LRPL Taylor    HM Nicholls  TK Curran                1
# 143   144     48.1  LRPL Taylor    HM Nicholls  CR Woakes                6
# 144   145     48.2  LRPL Taylor    HM Nicholls  CR Woakes                1
# 145   146     48.4  LRPL Taylor    HM Nicholls  CR Woakes                0
# 146   147     48.5  LRPL Taylor    HM Nicholls  CR Woakes                1
#
# ...

# %%
df1['Total_runs']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        4
#       ...
# 142    197
# 143    198
# 144    198
# 145    199
# 146    200
# Name: Total_runs, Length: 147, dtype: int64

# %%
df1['Bowler'].value_counts()
# Out:
# RE van der Merwe    32
# DW Steyn            31
# CK Langeveldt       28
# WD Parnell          24
# JP Duminy           17
# JH Kallis           15
# Name: Bowler, dtype: int64

# %%
# df1['Bowler'].value_counts()

a=df1[(df1['Bowler']=="RE van der Merwe") & (df1['Runs_by_batsman']>=0)]['Runs_by_batsman'].sum()
b=df1[(df1['Bowler']=="DW Steyn") & (df1['Runs_by_batsman']>=0)]['Runs_by_batsman'].sum()
c=df1[(df1['Bowler']=="CK Langeveldt") & (df1['Runs_by_batsman']>=0)]['Runs_by_batsman'].sum()
d=df1[(df1['Bowler']=="WD Parnell") & (df1['Runs_by_batsman']>=0)]['Runs_by_batsman'].sum()
e=df1[(df1['Bowler']=="JP Duminy") & (df1['Runs_by_batsman']>=0)]['Runs_by_batsman'].sum()
f=df1[(df1['Bowler']=="JH Kallis") & (df1['Runs_by_batsman']>=0)]['Runs_by_batsman'].sum()

# %%
data={'Bowler_name':['RE van der Merwe', 'DW Steyn', 'CK Langeveldt', 'WD Parnell', 'JP Duminy', 'JH Kallis'],'Runs_taken':[a,b,c,d,e,f]}

# %%
data.keys()
# Out:
# dict_keys(['Bowler_name', 'Runs_taken'])

# %%
data.values()
# Out:
# dict_values([['RE van der Merwe', 'DW Steyn', 'CK Langeveldt', 'WD Parnell', 'JP Duminy', 'JH Kallis'], [43, 37, 30, 46, 20, 24]])

# %%
df1['Bowler'].value_counts()
# Out:
# RE van der Merwe    32
# DW Steyn            31
# CK Langeveldt       28
# WD Parnell          24
# JP Duminy           17
# JH Kallis           15
# Name: Bowler, dtype: int64

# %%
# creating a data frame of runs conceived by each bowler in sachin's innings
sachin_bowl=pd.DataFrame(data,index=[1,2,3,4,5,6])

# %%
sachin_bowl
# Out:
#         Bowler_name  Runs_taken
# 1  RE van der Merwe          43
# 2          DW Steyn          37
# 3     CK Langeveldt          30
# 4        WD Parnell          46
# 5         JP Duminy          20
# 6         JH Kallis          24

# %%
df3['Bowler'].value_counts()
# Out:
# AU Rashid    34
# MM Ali       27
# MA Wood      23
# TK Curran    23
# BA Stokes    21
# CR Woakes    19
# Name: Bowler, dtype: int64

# %%
a=df3[(df3['Bowler']=="AU Rashid") & (df3['Runs_by_batsman']>=0)]['Runs_by_batsman'].sum()
b=df3[(df3['Bowler']=="MM Ali") & (df3['Runs_by_batsman']>=0)]['Runs_by_batsman'].sum()
c=df3[(df3['Bowler']=="MA Wood") & (df3['Runs_by_batsman']>=0)]['Runs_by_batsman'].sum()
d=df3[(df3['Bowler']=="TK Curran") & (df3['Runs_by_batsman']>=0)]['Runs_by_batsman'].sum()
e=df3[(df3['Bowler']=="BA Stokes") & (df3['Runs_by_batsman']>=0)]['Runs_by_batsman'].sum()
f=df3[(df3['Bowler']=="CR Woakes") & (df3['Runs_by_batsman']>=0)]['Runs_by_batsman'].sum()
print(a)
# alternate:run a for loop for getting each value and store that value in an array
# Out:
# 39

# %%
dict1={'Bowler_name':['AU Rashid','MM Ali','MA Wood','TK Curran','BA Stokes','CR Woakes'],
     'Runs_taken':[a,b,c,d,e,f]}

# %%
taylor_bowl=pd.DataFrame(dict1,index=[1,2,3,4,5,6])

# %%
taylor_bowl
# Out:
#   Bowler_name  Runs_taken
# 1   AU Rashid          39
# 2      MM Ali          29
# 3     MA Wood          35
# 4   TK Curran          23
# 5   BA Stokes          26
# 6   CR Woakes          29

# %%
fig=plt.figure(figsize=(15,10))
sns.barplot(taylor_bowl['Bowler_name'],taylor_bowl['Runs_taken'])
# Out:
# C:\Users\yashv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Bowler_name', ylabel='Runs_taken'>

# %%
fig=plt.figure(figsize=(15,10))
sns.barplot(sachin_bowl['Bowler_name'],taylor_bowl['Runs_taken'])
# Out:
# C:\Users\yashv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Bowler_name', ylabel='Runs_taken'>

# %%
sns.countplot(x=df1['Runs_by_batsman'],data=df1['Bowler']='DW Steyn')
# Out:
#   Input In [58]
#     sns.countplot(x=df1['Runs_by_batsman'],data=df1['Bowler']='DW Steyn')
#                                                              ^
# SyntaxError: invalid syntax

# %%
test=np.ceil(df1['Ball_no'])
df1['Over']=test
df1
# Out:
#      Ball  Ball_no       Striker Non_striker         Bowler  Runs_by_batsman  \
# 0       1      0.3  SR Tendulkar    V Sehwag       DW Steyn                0
# 1       2      0.4  SR Tendulkar    V Sehwag       DW Steyn                0
# 2       3      0.5  SR Tendulkar    V Sehwag       DW Steyn                0
# 3       4      0.6  SR Tendulkar    V Sehwag       DW Steyn                0
# 4       5      1.3  SR Tendulkar    V Sehwag     WD Parnell                4
# ..    ...      ...           ...         ...            ...              ...
# 142   143     46.4  SR Tendulkar    MS Dhoni       DW Steyn                0
# 143   144     46.5  SR Tendulkar    MS Dhoni       DW Steyn                1
# 144   145     47.3  SR Tendulkar    MS Dhoni  CK Langeveldt                0
# 145   146     47.4  SR Tendulkar    MS Dhoni  CK Langeveldt                1
# 146   147     49.3  SR Tendulkar    MS Dhoni  CK Langeveldt                1
#
# ...

# %%
df1[(df1['Runs_by_batsman']>=0) & (df1['Bowler']=='DW Steyn')]
# Out:
#      Ball  Ball_no       Striker Non_striker    Bowler  Runs_by_batsman  \
# 0       1      0.3  SR Tendulkar    V Sehwag  DW Steyn                0
# 1       2      0.4  SR Tendulkar    V Sehwag  DW Steyn                0
# 2       3      0.5  SR Tendulkar    V Sehwag  DW Steyn                0
# 3       4      0.6  SR Tendulkar    V Sehwag  DW Steyn                0
# 8       9      2.2  SR Tendulkar    V Sehwag  DW Steyn                1
# 9      10      2.6  SR Tendulkar    V Sehwag  DW Steyn                4
# 12     13      4.1  SR Tendulkar  KD Karthik  DW Steyn                0
# 13     14      4.2  SR Tendulkar  KD Karthik  DW Steyn                0
# 14     15      4.3  SR Tendulkar  KD Karthik  DW Steyn                4
# 15     16      4.4  SR Tendulkar  KD Karthik  DW Steyn                0
# 16     17      4.5  SR Tendulkar  KD Karthik  DW Steyn                2
# 17     18      4.6  SR Tendulkar  KD Karthik  DW Steyn                0
# ...

# %%
arr_s=df1[(df1['Runs_by_batsman']>=0) & (df1['Bowler']=='DW Steyn')]['Runs_by_batsman']

# %%
arr_s
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 8      1
# 9      4
# 12     0
# 13     0
# 14     4
# 15     0
# 16     2
# 17     0
# 18     0
# 19     4
# 20     0
# 21     0
# 22     1
# 27     1
# 32     1
# 104    0
# 105    4
# 106    0
# 107    0
# 108    4
# 109    1
# 114    4
# 115    0
# 116    4
# 141    1
# 142    0
# 143    1
# Name: Runs_by_batsman, dtype: int64

# %%
len(arr_s)
# Out:
# 31

# %%
dict_s={'Bowler_name':'DW Steyn','Run_type':arr_s}

# %%
Steyn=pd.DataFrame(dict_s)

# %%
Steyn
# Out:
#     Bowler_name  Run_type
# 0      DW Steyn         0
# 1      DW Steyn         0
# 2      DW Steyn         0
# 3      DW Steyn         0
# 8      DW Steyn         1
# 9      DW Steyn         4
# 12     DW Steyn         0
# 13     DW Steyn         0
# 14     DW Steyn         4
# 15     DW Steyn         0
# 16     DW Steyn         2
# 17     DW Steyn         0
# 18     DW Steyn         0
# 19     DW Steyn         4
# 20     DW Steyn         0
# 21     DW Steyn         0
# 22     DW Steyn         1
# 27     DW Steyn         1
# 32     DW Steyn         1
# 104    DW Steyn         0
# 105    DW Steyn         4
# 106    DW Steyn         0
# 107    DW Steyn         0
# 108    DW Steyn         4
# 109    DW Steyn         1
# 114    DW Steyn         4
# 115    DW Steyn         0
# 116    DW Steyn         4
# 141    DW Steyn         1
# 142    DW Steyn         0
# 143    DW Steyn         1

# %%
sns.countplot(x='Run_type',data=Steyn)
# Out:
# <AxesSubplot:xlabel='Run_type', ylabel='count'>

# %%
df1['Bowler'].value_counts()
# Out:
# RE van der Merwe    32
# DW Steyn            31
# CK Langeveldt       28
# WD Parnell          24
# JP Duminy           17
# JH Kallis           15
# Name: Bowler, dtype: int64

# %%
arr_s=df1[(df1['Runs_by_batsman']>=0) & (df1['Bowler']=='RE van der Merwe')]['Runs_by_batsman']
dict_s={'Bowler_name':'RE van der Merwe','Run_type':arr_s}
RE_van_der_Merwe=pd.DataFrame(dict_s)
sns.countplot(x='Run_type',data=RE_van_der_Merwe)
# Out:
# <AxesSubplot:xlabel='Run_type', ylabel='count'>

# %%
arr_s=df1[(df1['Runs_by_batsman']>=0) & (df1['Bowler']=='CK Langeveldt')]['Runs_by_batsman']
dict_s={'Bowler_name':'CK Langeveldt','Run_type':arr_s}
CK_Langeveldt=pd.DataFrame(dict_s)
sns.countplot(x='Run_type',data=CK_Langeveldt)
# Out:
# <AxesSubplot:xlabel='Run_type', ylabel='count'>

# %%
arr_s=df1[(df1['Runs_by_batsman']>=0) & (df1['Bowler']=='WD Parnell')]['Runs_by_batsman']
dict_s={'Bowler_name':'WD Parnell','Run_type':arr_s}
WD_Parnell=pd.DataFrame(dict_s)
sns.countplot(x='Run_type',data=WD_Parnell)
# Out:
# <AxesSubplot:xlabel='Run_type', ylabel='count'>

# %%
arr_s=df1[(df1['Runs_by_batsman']>=0) & (df1['Bowler']=='JP Duminy')]['Runs_by_batsman']
dict_s={'Bowler_name':'JP Duminy','Run_type':arr_s}
JP_Duminy=pd.DataFrame(dict_s)
sns.countplot(x='Run_type',data=JP_Duminy)
# Out:
# <AxesSubplot:xlabel='Run_type', ylabel='count'>

# %%
arr_s=df1[(df1['Runs_by_batsman']>=0) & (df1['Bowler']=='JH Kallis')]['Runs_by_batsman']
dict_s={'Bowler_name':'JH Kallis','Run_type':arr_s}
JH_Kallis=pd.DataFrame(dict_s)
sns.countplot(x='Run_type',data=JH_Kallis)
# Out:
# <AxesSubplot:xlabel='Run_type', ylabel='count'>

# %%
fig=plt.figure(figsize=(18,10))


plt.subplot(2,6,1)
plot1=sns.countplot(x='Run_type',data=Steyn)
plot1.set_title('Steyn')

plt.subplot(2,6,2)
plot2=sns.countplot(x='Run_type',data=RE_van_der_Merwe)
plot2.set_title('Merwe')  

plt.subplot(2,6,3)
plot3=sns.countplot(x='Run_type',data=CK_Langeveldt)
plot3.set_title('CK _Langeveldt')

plt.subplot(2,6,4)
plot4=sns.countplot(x='Run_type',data=WD_Parnell)
plot4.set_title('WD_Parnell')

plt.subplot(2,6,5)
plot5=sns.countplot(x='Run_type',data=JP_Duminy)
plot5.set_title('JP_Duminy')

plt.subplot(2,6,6)
plot6=sns.countplot(x='Run_type',data=JH_Kallis)
plot6.set_title('JH_Kallis')
# Out:
# Text(0.5, 1.0, 'JH_Kallis')

# %%
df3['Bowler'].value_counts()
# Out:
# AU Rashid    34
# MM Ali       27
# MA Wood      23
# TK Curran    23
# BA Stokes    21
# CR Woakes    19
# Name: Bowler, dtype: int64

# %%
arr_s=df3[(df3['Runs_by_batsman']>=0) & (df3['Bowler']=='AU Rashid')]['Runs_by_batsman']
dict_s={'Bowler_name':'AU Rashid','Run_type':arr_s}
AU_Rashid=pd.DataFrame(dict_s)
plot7=sns.countplot(x='Run_type',data=AU_Rashid)

arr_s=df3[(df3['Runs_by_batsman']>=0) & (df3['Bowler']=='MM Ali')]['Runs_by_batsman']
dict_s={'Bowler_name':'MM Ali','Run_type':arr_s}
MM_Ali=pd.DataFrame(dict_s)
plot8=sns.countplot(x='Run_type',data=MM_Ali)

arr_s=df3[(df3['Runs_by_batsman']>=0) & (df3['Bowler']=='MA Wood')]['Runs_by_batsman']
dict_s={'Bowler_name':'MA Wood','Run_type':arr_s}
MA_Wood=pd.DataFrame(dict_s)
plot9=sns.countplot(x='Run_type',data=MA_Wood)

arr_s=df3[(df3['Runs_by_batsman']>=0) & (df3['Bowler']=='TK Curran')]['Runs_by_batsman']
dict_s={'Bowler_name':'TK Curran','Run_type':arr_s}
TK_Curran=pd.DataFrame(dict_s)
plot10=sns.countplot(x='Run_type',data=TK_Curran)

arr_s=df3[(df3['Runs_by_batsman']>=0) & (df3['Bowler']=='BA Stokes')]['Runs_by_batsman']
dict_s={'Bowler_name':'BA Stokes','Run_type':arr_s}
BA_Stokes=pd.DataFrame(dict_s)
plot11=sns.countplot(x='Run_type',data=BA_Stokes)

arr_s=df3[(df3['Runs_by_batsman']>=0) & (df3['Bowler']=='CR Woakes')]['Runs_by_batsman']
dict_s={'Bowler_name':'CR Woakes','Run_type':arr_s}
CR_Woakes=pd.DataFrame(dict_s)
plot=sns.countplot(x='Run_type',data=CR_Woakes)
plot12=plot.set_title('Woakes')

# %%
df3['Bowler'].value_counts()
# Out:
# AU Rashid    34
# MM Ali       27
# MA Wood      23
# TK Curran    23
# BA Stokes    21
# CR Woakes    19
# Name: Bowler, dtype: int64

# %%
fig=plt.figure(figsize=(18,10))


plt.subplot(2,6,1)
plot7=sns.countplot(x='Run_type',data=AU_Rashid)
plot7.set_title('AU_Rashid')

plt.subplot(2,6,2)
plot2=sns.countplot(x='Run_type',data=MM_Ali)
plot2.set_title('MM_Ali')  

plt.subplot(2,6,3)
plot3=sns.countplot(x='Run_type',data=MA_Wood)
plot3.set_title('MA_Wood')

plt.subplot(2,6,4)
plot4=sns.countplot(x='Run_type',data=TK_Curran)
plot4.set_title('TK_Curran')

plt.subplot(2,6,5)
plot5=sns.countplot(x='Run_type',data=BA_Stokes)
plot5.set_title('BA_Stokes')

plt.subplot(2,6,6)
plot6=sns.countplot(x='Run_type',data=JH_Kallis)
plot6.set_title('CR_Woakes')
# Out:
# Text(0.5, 1.0, 'CR_Woakes')

# %%
taylor_bowl
# Out:
#   Bowler_name  Runs_taken
# 1   AU Rashid          39
# 2      MM Ali          29
# 3     MA Wood          35
# 4   TK Curran          23
# 5   BA Stokes          26
# 6   CR Woakes          29

# %%
df3['Bowler'].value_counts()
# Out:
# AU Rashid    34
# MM Ali       27
# MA Wood      23
# TK Curran    23
# BA Stokes    21
# CR Woakes    19
# Name: Bowler, dtype: int64

# %%
dict_taylor={'Bowler_name':taylor_bowl['Bowler_name'],'Balls_Bowled':[34,27,23,23,21,19]}

# %%
taylor_bowler=pd.DataFrame(data=dict_taylor)
taylor_bowler
# Out:
#   Bowler_name  Balls_Bowled
# 1   AU Rashid            34
# 2      MM Ali            27
# 3     MA Wood            23
# 4   TK Curran            23
# 5   BA Stokes            21
# 6   CR Woakes            19

# %%
taylor_df=pd.merge(taylor_bowler,taylor_bowl)
taylor_df['Runs_per_ball']=round(taylor_df['Runs_taken']/taylor_df['Balls_Bowled'],2)
taylor_df
# Out:
#   Bowler_name  Balls_Bowled  Runs_taken  Runs_per_ball
# 0   AU Rashid            34          39           1.15
# 1      MM Ali            27          29           1.07
# 2     MA Wood            23          35           1.52
# 3   TK Curran            23          23           1.00
# 4   BA Stokes            21          26           1.24
# 5   CR Woakes            19          29           1.53

# %%
sachin_bowl
# Out:
#         Bowler_name  Runs_taken
# 1  RE van der Merwe          43
# 2          DW Steyn          37
# 3     CK Langeveldt          30
# 4        WD Parnell          46
# 5         JP Duminy          20
# 6         JH Kallis          24

# %%
df1['Bowler'].value_counts()
# Out:
# RE van der Merwe    32
# DW Steyn            31
# CK Langeveldt       28
# WD Parnell          24
# JP Duminy           17
# JH Kallis           15
# Name: Bowler, dtype: int64

# %%
dict_sachin={'Bowler_name':sachin_bowl['Bowler_name'],'Balls_Bowled':[32,31,28,14,17,15]}

sachin_bowler=pd.DataFrame(data=dict_sachin)
sachin_bowler

sachin_df=pd.merge(sachin_bowler,sachin_bowl)
sachin_df['Runs_per_ball']=round(sachin_df['Runs_taken']/sachin_df['Balls_Bowled'],2)

sachin_df
# Out:
#         Bowler_name  Balls_Bowled  Runs_taken  Runs_per_ball
# 0  RE van der Merwe            32          43           1.34
# 1          DW Steyn            31          37           1.19
# 2     CK Langeveldt            28          30           1.07
# 3        WD Parnell            14          46           3.29
# 4         JP Duminy            17          20           1.18
# 5         JH Kallis            15          24           1.60

# %%
df1
# Out:
#      Ball  Ball_no       Striker Non_striker         Bowler  Runs_by_batsman  \
# 0       1      0.3  SR Tendulkar    V Sehwag       DW Steyn                0
# 1       2      0.4  SR Tendulkar    V Sehwag       DW Steyn                0
# 2       3      0.5  SR Tendulkar    V Sehwag       DW Steyn                0
# 3       4      0.6  SR Tendulkar    V Sehwag       DW Steyn                0
# 4       5      1.3  SR Tendulkar    V Sehwag     WD Parnell                4
# ..    ...      ...           ...         ...            ...              ...
# 142   143     46.4  SR Tendulkar    MS Dhoni       DW Steyn                0
# 143   144     46.5  SR Tendulkar    MS Dhoni       DW Steyn                1
# 144   145     47.3  SR Tendulkar    MS Dhoni  CK Langeveldt                0
# 145   146     47.4  SR Tendulkar    MS Dhoni  CK Langeveldt                1
# 146   147     49.3  SR Tendulkar    MS Dhoni  CK Langeveldt                1
#
# ...

# %%
test=np.ceil(df1['Ball_no'])
df1['Over']=test
sachin_run=df1[df1['Bowler']=='DW Steyn']
sachin_run
# Out:
#      Ball  Ball_no       Striker Non_striker    Bowler  Runs_by_batsman  \
# 0       1      0.3  SR Tendulkar    V Sehwag  DW Steyn                0
# 1       2      0.4  SR Tendulkar    V Sehwag  DW Steyn                0
# 2       3      0.5  SR Tendulkar    V Sehwag  DW Steyn                0
# 3       4      0.6  SR Tendulkar    V Sehwag  DW Steyn                0
# 8       9      2.2  SR Tendulkar    V Sehwag  DW Steyn                1
# 9      10      2.6  SR Tendulkar    V Sehwag  DW Steyn                4
# 12     13      4.1  SR Tendulkar  KD Karthik  DW Steyn                0
# 13     14      4.2  SR Tendulkar  KD Karthik  DW Steyn                0
# 14     15      4.3  SR Tendulkar  KD Karthik  DW Steyn                4
# 15     16      4.4  SR Tendulkar  KD Karthik  DW Steyn                0
# 16     17      4.5  SR Tendulkar  KD Karthik  DW Steyn                2
# 17     18      4.6  SR Tendulkar  KD Karthik  DW Steyn                0
# ...

# %%
x1=sachin_run[sachin_run['Over']==1.0]['Runs_by_batsman'].sum()
x1
# Out:
# 0

# %%
x2=sachin_run[sachin_run['Over']==3.0]['Runs_by_batsman'].sum()
x2
# Out:
# 5

# %%
x3=sachin_run[sachin_run['Over']==5.0]['Runs_by_batsman'].sum()
x3
# Out:
# 6

# %%
x4=sachin_run[sachin_run['Over']==7.0]['Runs_by_batsman'].sum()
x4
# Out:
# 5

# %%
x5=sachin_run[sachin_run['Over']==9.0]['Runs_by_batsman'].sum()
x5
# Out:
# 1

# %%
x6=sachin_run[sachin_run['Over']==11.0]['Runs_by_batsman'].sum()
x6
# Out:
# 1

# %%
x7=sachin_run[sachin_run['Over']==35.0]['Runs_by_batsman'].sum()
x7
# Out:
# 9

# %%
x8=sachin_run[sachin_run['Over']==37.0]['Runs_by_batsman'].sum()
x8
# Out:
# 8

# %%
x9=sachin_run[sachin_run['Over']==47.0]['Runs_by_batsman'].sum()
x9
# Out:
# 2

# %%
 dict_steyn={'Over':[1,3,5,7,9,11,35,37,47],'Runs':[x1,x2,x3,x4,x5,x6,x7,x8,x9]}

# %%
df_steyn=pd.DataFrame(data=dict_steyn)

# %%
df_steyn
# Out:
#    Over  Runs
# 0     1     0
# 1     3     5
# 2     5     6
# 3     7     5
# 4     9     1
# 5    11     1
# 6    35     9
# 7    37     8
# 8    47     2

# %%
test=np.ceil(df1['Ball_no'])
df1['Over']=test
sachin_run1=df1[df1['Bowler']=='RE van der Merwe']
sachin_run1
# Out:
#      Ball  Ball_no       Striker Non_striker            Bowler  \
# 33     34     11.1  SR Tendulkar  KD Karthik  RE van der Merwe
# 34     35     11.2  SR Tendulkar  KD Karthik  RE van der Merwe
# 35     36     11.3  SR Tendulkar  KD Karthik  RE van der Merwe
# 36     37     11.4  SR Tendulkar  KD Karthik  RE van der Merwe
# 37     38     11.5  SR Tendulkar  KD Karthik  RE van der Merwe
# 42     43     13.2  SR Tendulkar  KD Karthik  RE van der Merwe
# 43     44     13.6  SR Tendulkar  KD Karthik  RE van der Merwe
# 48     49     15.2  SR Tendulkar  KD Karthik  RE van der Merwe
# 49     50     15.3  SR Tendulkar  KD Karthik  RE van der Merwe
# 50     51     15.5  SR Tendulkar  KD Karthik  RE van der Merwe
# 52     53     17.1  SR Tendulkar  KD Karthik  RE van der Merwe
# 53     54     17.2  SR Tendulkar  KD Karthik  RE van der Merwe
# 54     55     17.6  SR Tendulkar  KD Karthik  RE van der Merwe
# 58     59     19.2  SR Tendulkar  KD Karthik  RE van der Merwe
# ...

# %%
sachin_run1
# Out:
#      Ball  Ball_no       Striker Non_striker            Bowler  \
# 33     34     11.1  SR Tendulkar  KD Karthik  RE van der Merwe
# 34     35     11.2  SR Tendulkar  KD Karthik  RE van der Merwe
# 35     36     11.3  SR Tendulkar  KD Karthik  RE van der Merwe
# 36     37     11.4  SR Tendulkar  KD Karthik  RE van der Merwe
# 37     38     11.5  SR Tendulkar  KD Karthik  RE van der Merwe
# 42     43     13.2  SR Tendulkar  KD Karthik  RE van der Merwe
# 43     44     13.6  SR Tendulkar  KD Karthik  RE van der Merwe
# 48     49     15.2  SR Tendulkar  KD Karthik  RE van der Merwe
# 49     50     15.3  SR Tendulkar  KD Karthik  RE van der Merwe
# 50     51     15.5  SR Tendulkar  KD Karthik  RE van der Merwe
# 52     53     17.1  SR Tendulkar  KD Karthik  RE van der Merwe
# 53     54     17.2  SR Tendulkar  KD Karthik  RE van der Merwe
# 54     55     17.6  SR Tendulkar  KD Karthik  RE van der Merwe
# 58     59     19.2  SR Tendulkar  KD Karthik  RE van der Merwe
# ...

# %%
sachin_run1['Over'].value_counts(ascending=True)
# Out:
# 14.0    2
# 33.0    2
# 16.0    3
# 18.0    3
# 20.0    3
# 31.0    3
# 40.0    3
# 42.0    3
# 12.0    5
# 22.0    5
# Name: Over, dtype: int64

# %%
test_arr=[]
test_arr.append(sachin_run1[sachin_run1['Over']==12.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run1[sachin_run1['Over']==14.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run1[sachin_run1['Over']==16.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run1[sachin_run1['Over']==18.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run1[sachin_run1['Over']==20.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run1[sachin_run1['Over']==22.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run1[sachin_run1['Over']==31.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run1[sachin_run1['Over']==33.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run1[sachin_run1['Over']==40.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run1[sachin_run1['Over']==42.0]['Runs_by_batsman'].sum())

# %%
test_arr
# Out:
# [5, 2, 5, 4, 5, 5, 1, 2, 3, 11]

# %%
dict_Merwe={'Over':sachin_run1['Over'].unique(),'Runs':test_arr}

# %%
dict_Merwe.values()
# Out:
# dict_values([array([12., 14., 16., 18., 20., 22., 31., 33., 40., 42.]), [5, 2, 5, 4, 5, 5, 1, 2, 3, 11]])

# %%
df_Merwe=pd.DataFrame(data=dict_Merwe)

# %%
df_Merwe
# Out:
#    Over  Runs
# 0  12.0     5
# 1  14.0     2
# 2  16.0     5
# 3  18.0     4
# 4  20.0     5
# 5  22.0     5
# 6  31.0     1
# 7  33.0     2
# 8  40.0     3
# 9  42.0    11

# %%
df1
# Out:
#      Ball  Ball_no       Striker Non_striker         Bowler  Runs_by_batsman  \
# 0       1      0.3  SR Tendulkar    V Sehwag       DW Steyn                0
# 1       2      0.4  SR Tendulkar    V Sehwag       DW Steyn                0
# 2       3      0.5  SR Tendulkar    V Sehwag       DW Steyn                0
# 3       4      0.6  SR Tendulkar    V Sehwag       DW Steyn                0
# 4       5      1.3  SR Tendulkar    V Sehwag     WD Parnell                4
# ..    ...      ...           ...         ...            ...              ...
# 142   143     46.4  SR Tendulkar    MS Dhoni       DW Steyn                0
# 143   144     46.5  SR Tendulkar    MS Dhoni       DW Steyn                1
# 144   145     47.3  SR Tendulkar    MS Dhoni  CK Langeveldt                0
# 145   146     47.4  SR Tendulkar    MS Dhoni  CK Langeveldt                1
# 146   147     49.3  SR Tendulkar    MS Dhoni  CK Langeveldt                1
#
# ...

# %%
test=np.ceil(df1['Ball_no'])
df1['Over']=test
sachin_run2=df1[df1['Bowler']=='CK Langeveldt']
sachin_run2
# Out:
#      Ball  Ball_no       Striker Non_striker         Bowler  Runs_by_batsman  \
# 38     39     12.3  SR Tendulkar  KD Karthik  CK Langeveldt                0
# 39     40     12.4  SR Tendulkar  KD Karthik  CK Langeveldt                0
# 40     41     12.5  SR Tendulkar  KD Karthik  CK Langeveldt                2
# 41     42     12.7  SR Tendulkar  KD Karthik  CK Langeveldt                0
# 44     45     14.1  SR Tendulkar  KD Karthik  CK Langeveldt                2
# 45     46     14.2  SR Tendulkar  KD Karthik  CK Langeveldt                0
# 46     47     14.3  SR Tendulkar  KD Karthik  CK Langeveldt                4
# 47     48     14.4  SR Tendulkar  KD Karthik  CK Langeveldt                0
# 51     52     16.3  SR Tendulkar  KD Karthik  CK Langeveldt                1
# 55     56     18.1  SR Tendulkar  KD Karthik  CK Langeveldt                0
# 56     57     18.2  SR Tendulkar  KD Karthik  CK Langeveldt                1
# ...

# %%
sachin_run2['Over'].nunique()
# Out:
# 10

# %%
test_arr=[]
test_arr.append(sachin_run2[sachin_run2['Over']==13.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run2[sachin_run2['Over']==15.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run2[sachin_run2['Over']==17.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run2[sachin_run2['Over']==19.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run2[sachin_run2['Over']==21.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run2[sachin_run2['Over']==23.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run2[sachin_run2['Over']==39.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run2[sachin_run2['Over']==41.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run2[sachin_run2['Over']==48.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run2[sachin_run2['Over']==50.0]['Runs_by_batsman'].sum())

# %%
test_arr
# Out:
# [2, 6, 1, 2, 3, 1, 5, 8, 1, 1]

# %%
dict_Langeveldt={'Over':sachin_run2['Over'].unique(),'Runs':test_arr}
df_Langeveldt=pd.DataFrame(data=dict_Langeveldt)

# %%
df_Langeveldt
# Out:
#    Over  Runs
# 0  13.0     2
# 1  15.0     6
# 2  17.0     1
# 3  19.0     2
# 4  21.0     3
# 5  23.0     1
# 6  39.0     5
# 7  41.0     8
# 8  48.0     1
# 9  50.0     1

# %%
test=np.ceil(df1['Ball_no'])
df1['Over']=test
sachin_run3=df1[df1['Bowler']=='WD Parnell']
sachin_run3
# Out:
#      Ball  Ball_no       Striker Non_striker      Bowler  Runs_by_batsman  \
# 4       5      1.3  SR Tendulkar    V Sehwag  WD Parnell                4
# 5       6      1.4  SR Tendulkar    V Sehwag  WD Parnell                4
# 6       7      1.5  SR Tendulkar    V Sehwag  WD Parnell                0
# 7       8      1.6  SR Tendulkar    V Sehwag  WD Parnell                2
# 10     11      3.3  SR Tendulkar    V Sehwag  WD Parnell                0
# 11     12      3.4  SR Tendulkar    V Sehwag  WD Parnell                1
# 23     24      7.1  SR Tendulkar  KD Karthik  WD Parnell                2
# 24     25      7.2  SR Tendulkar  KD Karthik  WD Parnell                4
# 25     26      7.3  SR Tendulkar  KD Karthik  WD Parnell                2
# 26     27      7.4  SR Tendulkar  KD Karthik  WD Parnell                1
# 28     29      9.1  SR Tendulkar  KD Karthik  WD Parnell                4
# 29     30      9.2  SR Tendulkar  KD Karthik  WD Parnell                1
# ...

# %%
sachin_run3['Over'].nunique()
# Out:
# 8

# %%
test_arr=[]
test_arr.append(sachin_run3[sachin_run3['Over']==2.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run3[sachin_run3['Over']==4.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run3[sachin_run3['Over']==8.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run3[sachin_run3['Over']==10.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run3[sachin_run3['Over']==36.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run3[sachin_run3['Over']==38.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run3[sachin_run3['Over']==44.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run3[sachin_run3['Over']==46.0]['Runs_by_batsman'].sum())

# %%
dict_WD_Parnell={'Over':sachin_run3['Over'].unique(),'Runs':test_arr}
df_WD_Parnell=pd.DataFrame(data=dict_WD_Parnell)

# %%
df_WD_Parnell
# Out:
#    Over  Runs
# 0   2.0    10
# 1   4.0     1
# 2   8.0     9
# 3  10.0     9
# 4  36.0     6
# 5  38.0     5
# 6  44.0     1
# 7  46.0     5

# %%
test=np.ceil(df1['Ball_no'])
df1['Over']=test
sachin_run4=df1[df1['Bowler']=='JP Duminy']
sachin_run4
# Out:
#      Ball  Ball_no       Striker Non_striker     Bowler  Runs_by_batsman  \
# 73     74     23.2  SR Tendulkar  KD Karthik  JP Duminy                1
# 74     75     23.4  SR Tendulkar  KD Karthik  JP Duminy                2
# 75     76     23.5  SR Tendulkar  KD Karthik  JP Duminy                0
# 76     77     23.6  SR Tendulkar  KD Karthik  JP Duminy                0
# 79     80     25.1  SR Tendulkar  KD Karthik  JP Duminy                0
# 80     81     25.2  SR Tendulkar  KD Karthik  JP Duminy                0
# 81     82     25.3  SR Tendulkar  KD Karthik  JP Duminy                1
# 82     83     25.5  SR Tendulkar  KD Karthik  JP Duminy                0
# 83     84     25.6  SR Tendulkar  KD Karthik  JP Duminy                1
# 86     87     27.1  SR Tendulkar  KD Karthik  JP Duminy                0
# 87     88     27.2  SR Tendulkar  KD Karthik  JP Duminy                1
# 88     89     27.4  SR Tendulkar  KD Karthik  JP Duminy                1
# ...

# %%
sachin_run4['Over'].nunique()
# Out:
# 5

# %%
test_arr=[]
test_arr.append(sachin_run4[sachin_run4['Over']==24.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run4[sachin_run4['Over']==26.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run4[sachin_run4['Over']==28.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run4[sachin_run4['Over']==30.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run4[sachin_run4['Over']==32.0]['Runs_by_batsman'].sum())

# %%
dict_JP_Duminy={'Over':sachin_run4['Over'].unique(),'Runs':test_arr}
df_JP_Duminy=pd.DataFrame(data=dict_JP_Duminy)
df_JP_Duminy
# Out:
#    Over  Runs
# 0  24.0     3
# 1  26.0     2
# 2  28.0     3
# 3  30.0     1
# 4  32.0    11

# %%
test=np.ceil(df1['Ball_no'])
df1['Over']=test
sachin_run5=df1[df1['Bowler']=='JH Kallis']
sachin_run5
# Out:
#      Ball  Ball_no       Striker Non_striker     Bowler  Runs_by_batsman  \
# 77     78     24.4  SR Tendulkar  KD Karthik  JH Kallis                1
# 78     79     24.7  SR Tendulkar  KD Karthik  JH Kallis                1
# 84     85     26.1  SR Tendulkar  KD Karthik  JH Kallis                1
# 85     86     26.6  SR Tendulkar  KD Karthik  JH Kallis                1
# 90     91     28.1  SR Tendulkar  KD Karthik  JH Kallis                4
# 91     92     28.2  SR Tendulkar  KD Karthik  JH Kallis                0
# 92     93     28.3  SR Tendulkar  KD Karthik  JH Kallis                4
# 93     94     28.4  SR Tendulkar  KD Karthik  JH Kallis                1
# 94     95     28.6  SR Tendulkar  KD Karthik  JH Kallis                0
# 131   132     42.2  SR Tendulkar    MS Dhoni  JH Kallis                1
# 132   133     42.5  SR Tendulkar    MS Dhoni  JH Kallis                2
# 133   134     42.6  SR Tendulkar    MS Dhoni  JH Kallis                4
# ...

# %%
sachin_run5['Over'].nunique()
# Out:
# 5

# %%
test_arr=[]
test_arr.append(sachin_run5[sachin_run5['Over']==25.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run5[sachin_run5['Over']==27.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run5[sachin_run5['Over']==29.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run5[sachin_run5['Over']==43.0]['Runs_by_batsman'].sum())
test_arr.append(sachin_run5[sachin_run5['Over']==45.0]['Runs_by_batsman'].sum())
test_arr
# Out:
# [2, 2, 9, 7, 4]

# %%
dict_JH_Kallis={'Over':sachin_run5['Over'].unique(),'Runs':test_arr}
df_JH_Kallis=pd.DataFrame(data=dict_JH_Kallis)
df_JH_Kallis
# Out:
#    Over  Runs
# 0  25.0     2
# 1  27.0     2
# 2  29.0     9
# 3  43.0     7
# 4  45.0     4

# %%
df3
# Out:
#      Ball  Ball_No      Striker    Non_striker     Bowler  Runs_by_batsman  \
# 0       1      3.1  LRPL Taylor  KS Williamson    MA Wood                0
# 1       2      3.2  LRPL Taylor  KS Williamson    MA Wood                0
# 2       3      3.3  LRPL Taylor  KS Williamson    MA Wood                0
# 3       4      3.4  LRPL Taylor  KS Williamson    MA Wood                0
# 4       5      3.5  LRPL Taylor  KS Williamson    MA Wood                0
# ..    ...      ...          ...            ...        ...              ...
# 142   143     47.5  LRPL Taylor    HM Nicholls  TK Curran                1
# 143   144     48.1  LRPL Taylor    HM Nicholls  CR Woakes                6
# 144   145     48.2  LRPL Taylor    HM Nicholls  CR Woakes                1
# 145   146     48.4  LRPL Taylor    HM Nicholls  CR Woakes                0
# 146   147     48.5  LRPL Taylor    HM Nicholls  CR Woakes                1
#
# ...

# %%
test=np.ceil(df3['Ball_No'])
df3['Over']=test
taylor_run6=df3[df3['Bowler']=='AU Rashid']
taylor_run6
# Out:
#      Ball  Ball_No      Striker      Non_striker     Bowler  Runs_by_batsman  \
# 20     21     10.2  LRPL Taylor    KS Williamson  AU Rashid                4
# 21     22     10.3  LRPL Taylor    KS Williamson  AU Rashid                0
# 22     23     10.4  LRPL Taylor    KS Williamson  AU Rashid                1
# 23     24     10.6  LRPL Taylor    KS Williamson  AU Rashid                1
# 28     29     12.3  LRPL Taylor    KS Williamson  AU Rashid                1
# 29     30     12.6  LRPL Taylor    KS Williamson  AU Rashid                0
# 32     33     14.2  LRPL Taylor    KS Williamson  AU Rashid                0
# 33     34     14.3  LRPL Taylor    KS Williamson  AU Rashid                1
# 34     35     14.6  LRPL Taylor    KS Williamson  AU Rashid                4
# 68     69     26.2  LRPL Taylor       TWM Latham  AU Rashid                0
# 69     70     26.3  LRPL Taylor       TWM Latham  AU Rashid                2
# ...

# %%
taylor_run6['Over'].unique()
# Out:
# array([11., 13., 15., 27., 29., 31., 33., 35., 41., 43.])

# %%
test_arr=[]
test_arr.append(taylor_run6[taylor_run6['Over']==11.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run6[taylor_run6['Over']==13.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run6[taylor_run6['Over']==15.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run6[taylor_run6['Over']==27.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run6[taylor_run6['Over']==29.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run6[taylor_run6['Over']==31.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run6[taylor_run6['Over']==33.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run6[taylor_run6['Over']==35.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run6[taylor_run6['Over']==41.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run6[taylor_run6['Over']==43.0]['Runs_by_batsman'].sum())

# %%
test_arr
# Out:
# [6, 1, 5, 3, 3, 2, 6, 2, 8, 3]

# %%
dict_AU_Rashid={'Over':taylor_run6['Over'].unique(),'Runs':test_arr}
df_AU_Rashid=pd.DataFrame(data=dict_AU_Rashid)
df_AU_Rashid
# Out:
#    Over  Runs
# 0  11.0     6
# 1  13.0     1
# 2  15.0     5
# 3  27.0     3
# 4  29.0     3
# 5  31.0     2
# 6  33.0     6
# 7  35.0     2
# 8  41.0     8
# 9  43.0     3

# %%
taylor_df
# Out:
#   Bowler_name  Balls_Bowled  Runs_taken  Runs_per_ball
# 0   AU Rashid            34          39           1.15
# 1      MM Ali            27          29           1.07
# 2     MA Wood            23          35           1.52
# 3   TK Curran            23          23           1.00
# 4   BA Stokes            21          26           1.24
# 5   CR Woakes            19          29           1.53

# %%
test=np.ceil(df3['Ball_No'])
df3['Over']=test
taylor_run7=df3[df3['Bowler']=='MM Ali']
taylor_run7
# Out:
#     Ball  Ball_No      Striker Non_striker  Bowler  Runs_by_batsman  \
# 46    47     19.3  LRPL Taylor  TWM Latham  MM Ali                1
# 50    51     21.1  LRPL Taylor  TWM Latham  MM Ali                1
# 51    52     21.6  LRPL Taylor  TWM Latham  MM Ali                1
# 55    56     23.1  LRPL Taylor  TWM Latham  MM Ali                0
# 56    57     23.2  LRPL Taylor  TWM Latham  MM Ali                0
# 57    58     23.3  LRPL Taylor  TWM Latham  MM Ali                0
# 58    59     23.4  LRPL Taylor  TWM Latham  MM Ali                0
# 59    60     23.5  LRPL Taylor  TWM Latham  MM Ali                0
# 60    61     23.6  LRPL Taylor  TWM Latham  MM Ali                1
# 64    65     25.2  LRPL Taylor  TWM Latham  MM Ali                1
# 65    66     25.4  LRPL Taylor  TWM Latham  MM Ali                0
# 66    67     25.5  LRPL Taylor  TWM Latham  MM Ali                0
# 67    68     25.6  LRPL Taylor  TWM Latham  MM Ali                0
# ...

# %%
taylor_run7['Over'].unique()
# Out:
# array([20., 22., 24., 26., 28., 30., 32., 34.])

# %%
test_arr=[]
test_arr.append(taylor_run7[taylor_run7['Over']==20.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run7[taylor_run7['Over']==22.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run7[taylor_run7['Over']==24.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run7[taylor_run7['Over']==26.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run7[taylor_run7['Over']==28.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run7[taylor_run7['Over']==30.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run7[taylor_run7['Over']==32.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run7[taylor_run7['Over']==34.0]['Runs_by_batsman'].sum())

# %%
dict_MM_Ali={'Over':taylor_run7['Over'].unique(),'Runs':test_arr}
df_MM_Ali=pd.DataFrame(data=dict_MM_Ali)
df_MM_Ali
# Out:
#    Over  Runs
# 0  20.0     1
# 1  22.0     2
# 2  24.0     1
# 3  26.0     1
# 4  28.0    11
# 5  30.0     2
# 6  32.0     2
# 7  34.0     9

# %%
test=np.ceil(df3['Ball_No'])
df3['Over']=test
taylor_run8=df3[df3['Bowler']=='MA Wood']
taylor_run8
# Out:
#      Ball  Ball_No      Striker    Non_striker   Bowler  Runs_by_batsman  \
# 0       1      3.1  LRPL Taylor  KS Williamson  MA Wood                0
# 1       2      3.2  LRPL Taylor  KS Williamson  MA Wood                0
# 2       3      3.3  LRPL Taylor  KS Williamson  MA Wood                0
# 3       4      3.4  LRPL Taylor  KS Williamson  MA Wood                0
# 4       5      3.5  LRPL Taylor  KS Williamson  MA Wood                0
# 5       6      3.6  LRPL Taylor  KS Williamson  MA Wood                1
# 7       8      5.4  LRPL Taylor  KS Williamson  MA Wood                0
# 8       9      5.5  LRPL Taylor  KS Williamson  MA Wood                1
# 14     15      7.1  LRPL Taylor  KS Williamson  MA Wood                1
# 16     17      9.1  LRPL Taylor  KS Williamson  MA Wood                0
# 17     18      9.2  LRPL Taylor  KS Williamson  MA Wood                6
# 18     19      9.3  LRPL Taylor  KS Williamson  MA Wood                4
# ...

# %%
taylor_run8['Over'].unique()
# Out:
# array([ 4.,  6.,  8., 10., 36., 38., 40.])

# %%
test_arr=[]
test_arr.append(taylor_run8[taylor_run8['Over']==4.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run8[taylor_run8['Over']==6.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run8[taylor_run8['Over']==8.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run8[taylor_run8['Over']==10.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run8[taylor_run8['Over']==36.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run8[taylor_run8['Over']==38.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run8[taylor_run8['Over']==40.0]['Runs_by_batsman'].sum())

# %%
dict_MA_Wood={'Over':taylor_run8['Over'].unique(),'Runs':test_arr}
df_MA_Wood=pd.DataFrame(data=dict_MA_Wood)
df_MA_Wood
# Out:
#    Over  Runs
# 0   4.0     1
# 1   6.0     1
# 2   8.0     1
# 3  10.0    11
# 4  36.0     6
# 5  38.0     2
# 6  40.0    13

# %%
test=np.ceil(df3['Ball_No'])
df3['Over']=test
taylor_run9=df3[df3['Bowler']=='TK Curran']
taylor_run9
# Out:
#      Ball  Ball_No      Striker      Non_striker     Bowler  Runs_by_batsman  \
# 24     25     11.1  LRPL Taylor    KS Williamson  TK Curran                4
# 25     26     11.2  LRPL Taylor    KS Williamson  TK Curran                0
# 26     27     11.3  LRPL Taylor    KS Williamson  TK Curran                0
# 27     28     11.4  LRPL Taylor    KS Williamson  TK Curran                1
# 30     31     13.2  LRPL Taylor    KS Williamson  TK Curran                1
# 31     32     13.4  LRPL Taylor    KS Williamson  TK Curran                1
# 35     36     15.3  LRPL Taylor    KS Williamson  TK Curran                0
# 36     37     15.4  LRPL Taylor    KS Williamson  TK Curran                1
# 37     38     15.6  LRPL Taylor    KS Williamson  TK Curran                0
# 40     41     17.1  LRPL Taylor       TWM Latham  TK Curran                0
# 41     42     17.2  LRPL Taylor       TWM Latham  TK Curran                4
# ...

# %%
taylor_run9['Over'].unique()
# Out:
# array([12., 14., 16., 18., 42., 44., 46., 48.])

# %%
test_arr=[]
test_arr.append(taylor_run9[taylor_run9['Over']==12.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run9[taylor_run9['Over']==14.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run9[taylor_run9['Over']==16.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run9[taylor_run9['Over']==18.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run9[taylor_run9['Over']==42.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run9[taylor_run9['Over']==44.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run9[taylor_run9['Over']==46.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run9[taylor_run9['Over']==48.0]['Runs_by_batsman'].sum())

# %%
test_arr
# Out:
# [5, 2, 1, 5, 6, 1, 1, 2]

# %%
dict_TK_Curran={'Over':taylor_run9['Over'].unique(),'Runs':test_arr}
df_TK_Curran=pd.DataFrame(data=dict_TK_Curran)
df_TK_Curran
# Out:
#    Over  Runs
# 0  12.0     5
# 1  14.0     2
# 2  16.0     1
# 3  18.0     5
# 4  42.0     6
# 5  44.0     1
# 6  46.0     1
# 7  48.0     2

# %%
test=np.ceil(df3['Ball_No'])
df3['Over']=test
taylor_run10=df3[df3['Bowler']=='BA Stokes']
taylor_run10
# Out:
#      Ball  Ball_No      Striker Non_striker     Bowler  Runs_by_batsman  \
# 38     39     16.3  LRPL Taylor  TWM Latham  BA Stokes                1
# 39     40     16.6  LRPL Taylor  TWM Latham  BA Stokes                1
# 44     45     18.4  LRPL Taylor  TWM Latham  BA Stokes                0
# 45     46     18.5  LRPL Taylor  TWM Latham  BA Stokes                1
# 47     48     20.1  LRPL Taylor  TWM Latham  BA Stokes                1
# 48     49     20.3  LRPL Taylor  TWM Latham  BA Stokes                1
# 49     50     20.5  LRPL Taylor  TWM Latham  BA Stokes                1
# 52     53     22.1  LRPL Taylor  TWM Latham  BA Stokes                0
# 53     54     22.2  LRPL Taylor  TWM Latham  BA Stokes                1
# 54     55     22.6  LRPL Taylor  TWM Latham  BA Stokes                1
# 61     62     24.1  LRPL Taylor  TWM Latham  BA Stokes                0
# 62     63     24.2  LRPL Taylor  TWM Latham  BA Stokes                1
# ...

# %%
taylor_run10['Over'].unique()
# Out:
# array([17., 19., 21., 23., 25., 37., 39.])

# %%
test_arr=[]
test_arr.append(taylor_run10[taylor_run10['Over']==17.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run10[taylor_run10['Over']==19.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run10[taylor_run10['Over']==21.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run10[taylor_run10['Over']==23.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run10[taylor_run10['Over']==25.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run10[taylor_run10['Over']==37.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run10[taylor_run10['Over']==39.0]['Runs_by_batsman'].sum())

# %%
test_arr
# Out:
# [2, 1, 3, 2, 2, 4, 12]

# %%
dict_BA_Stokes={'Over':taylor_run10['Over'].unique(),'Runs':test_arr}
df_BA_Stokes=pd.DataFrame(data=dict_BA_Stokes)
df_BA_Stokes
# Out:
#    Over  Runs
# 0  17.0     2
# 1  19.0     1
# 2  21.0     3
# 3  23.0     2
# 4  25.0     2
# 5  37.0     4
# 6  39.0    12

# %%
test=np.ceil(df3['Ball_No'])
df3['Over']=test
taylor_run11=df3[df3['Bowler']=='CR Woakes']
taylor_run11
# Out:
#      Ball  Ball_No      Striker      Non_striker     Bowler  Runs_by_batsman  \
# 6       7      4.1  LRPL Taylor    KS Williamson  CR Woakes                1
# 9      10      6.1  LRPL Taylor    KS Williamson  CR Woakes                4
# 10     11      6.2  LRPL Taylor    KS Williamson  CR Woakes                0
# 11     12      6.3  LRPL Taylor    KS Williamson  CR Woakes                0
# 12     13      6.4  LRPL Taylor    KS Williamson  CR Woakes                0
# 13     14      6.5  LRPL Taylor    KS Williamson  CR Woakes                1
# 15     16      8.5  LRPL Taylor    KS Williamson  CR Woakes                0
# 130   131     44.1  LRPL Taylor  C de Grandhomme  CR Woakes                0
# 131   132     44.2  LRPL Taylor  C de Grandhomme  CR Woakes                1
# 132   133     44.4  LRPL Taylor  C de Grandhomme  CR Woakes                0
# 133   134     44.5  LRPL Taylor  C de Grandhomme  CR Woakes                1
# ...

# %%
taylor_run11['Over'].unique()
# Out:
# array([ 5.,  7.,  9., 45., 47., 49.])

# %%
test_arr=[]
test_arr.append(taylor_run11[taylor_run11['Over']==5.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run11[taylor_run11['Over']==7.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run11[taylor_run11['Over']==9.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run11[taylor_run11['Over']==45.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run11[taylor_run11['Over']==47.0]['Runs_by_batsman'].sum())
test_arr.append(taylor_run11[taylor_run11['Over']==49.0]['Runs_by_batsman'].sum())

# %%
test_arr
# Out:
# [1, 5, 0, 2, 13, 8]

# %%
dict_CR_Woakes={'Over':taylor_run11['Over'].unique(),'Runs':test_arr}
df_CR_Woakes=pd.DataFrame(data=dict_CR_Woakes)
df_CR_Woakes
# Out:
#    Over  Runs
# 0   5.0     1
# 1   7.0     5
# 2   9.0     0
# 3  45.0     2
# 4  47.0    13
# 5  49.0     8

# %%
Steyn['Over']=sachin_run['Over']

# %%
Steyn_final
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [161], in <cell line: 1>()
# ----> 1 Steyn_final
#
# NameError: name 'Steyn_final' is not defined

# %%
Steyn
# Out:
#     Bowler_name  Run_type  Over
# 0      DW Steyn         0   1.0
# 1      DW Steyn         0   1.0
# 2      DW Steyn         0   1.0
# 3      DW Steyn         0   1.0
# 8      DW Steyn         1   3.0
# 9      DW Steyn         4   3.0
# 12     DW Steyn         0   5.0
# 13     DW Steyn         0   5.0
# 14     DW Steyn         4   5.0
# 15     DW Steyn         0   5.0
# 16     DW Steyn         2   5.0
# 17     DW Steyn         0   5.0
# 18     DW Steyn         0   7.0
# 19     DW Steyn         4   7.0
# 20     DW Steyn         0   7.0
# 21     DW Steyn         0   7.0
# 22     DW Steyn         1   7.0
# 27     DW Steyn         1   9.0
# 32     DW Steyn         1  11.0
# 104    DW Steyn         0  35.0
# 105    DW Steyn         4  35.0
# 106    DW Steyn         0  35.0
# 107    DW Steyn         0  35.0
# 108    DW Steyn         4  35.0
# 109    DW Steyn         1  35.0
# 114    DW Steyn         4  37.0
# 115    DW Steyn         0  37.0
# 116    DW Steyn         4  37.0
# ...

# %%
df_steyn
# Out:
#    Over  Runs
# 0     1     0
# 1     3     5
# 2     5     6
# 3     7     5
# 4     9     1
# 5    11     1
# 6    35     9
# 7    37     8
# 8    47     2

# %%
bc=pd.merge(Steyn,df_steyn,on="Over")

# %%
bc
# Out:
#    Bowler_name  Run_type  Over  Runs
# 0     DW Steyn         0   1.0     0
# 1     DW Steyn         0   1.0     0
# 2     DW Steyn         0   1.0     0
# 3     DW Steyn         0   1.0     0
# 4     DW Steyn         1   3.0     5
# 5     DW Steyn         4   3.0     5
# 6     DW Steyn         0   5.0     6
# 7     DW Steyn         0   5.0     6
# 8     DW Steyn         4   5.0     6
# 9     DW Steyn         0   5.0     6
# 10    DW Steyn         2   5.0     6
# 11    DW Steyn         0   5.0     6
# 12    DW Steyn         0   7.0     5
# 13    DW Steyn         4   7.0     5
# 14    DW Steyn         0   7.0     5
# 15    DW Steyn         0   7.0     5
# 16    DW Steyn         1   7.0     5
# 17    DW Steyn         1   9.0     1
# 18    DW Steyn         1  11.0     1
# 19    DW Steyn         0  35.0     9
# 20    DW Steyn         4  35.0     9
# 21    DW Steyn         0  35.0     9
# 22    DW Steyn         0  35.0     9
# 23    DW Steyn         4  35.0     9
# ...

# %%
sns.barplot(x=df_steyn['Over'],y=df_steyn['Runs'])
# Out:
# <AxesSubplot:xlabel='Over', ylabel='Runs'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=bc['Over'],y=bc['Runs'],hue=bc['Run_type'])
# Out:
# <AxesSubplot:xlabel='Over', ylabel='Runs'>

# %%
bc
# Out:
#    Bowler_name  Run_type  Over  Runs
# 0     DW Steyn         0     1     0
# 1     DW Steyn         0     1     0
# 2     DW Steyn         0     1     0
# 3     DW Steyn         0     1     0
# 4     DW Steyn         1     3     5
# 5     DW Steyn         4     3     5
# 6     DW Steyn         0     5     6
# 7     DW Steyn         0     5     6
# 8     DW Steyn         4     5     6
# 9     DW Steyn         0     5     6
# 10    DW Steyn         2     5     6
# 11    DW Steyn         0     5     6
# 12    DW Steyn         0     7     5
# 13    DW Steyn         4     7     5
# 14    DW Steyn         0     7     5
# 15    DW Steyn         0     7     5
# 16    DW Steyn         1     7     5
# 17    DW Steyn         1     9     1
# 18    DW Steyn         1    11     1
# 19    DW Steyn         0    35     9
# 20    DW Steyn         4    35     9
# 21    DW Steyn         0    35     9
# 22    DW Steyn         0    35     9
# 23    DW Steyn         4    35     9
# ...

# %%
sns.countplot('Over',data=bc)
# Out:
# C:\Users\yashv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Over', ylabel='count'>

# %%
RE_van_der_Merwe
RE_van_der_Merwe.rename(columns = {'Run_type':'Runs'}, inplace = True)
RE_van_der_Merwe
RE_van_der_Merwe.rename(columns = {'Run':'Runs'}, inplace = True)
RE_van_der_Merwe
# Out:
#           Bowler_name  Runs
# 33   RE van der Merwe     0
# 34   RE van der Merwe     0
# 35   RE van der Merwe     0
# 36   RE van der Merwe     4
# 37   RE van der Merwe     1
# 42   RE van der Merwe     1
# 43   RE van der Merwe     1
# 48   RE van der Merwe     4
# 49   RE van der Merwe     1
# 50   RE van der Merwe     0
# 52   RE van der Merwe     2
# 53   RE van der Merwe     1
# 54   RE van der Merwe     1
# 58   RE van der Merwe     0
# 59   RE van der Merwe     1
# 60   RE van der Merwe     4
# 64   RE van der Merwe     0
# 65   RE van der Merwe     0
# 66   RE van der Merwe     4
# 67   RE van der Merwe     1
# 68   RE van der Merwe     0
# 96   RE van der Merwe     0
# 97   RE van der Merwe     0
# 98   RE van der Merwe     1
# 102  RE van der Merwe     1
# 103  RE van der Merwe     1
# 122  RE van der Merwe     0
# 123  RE van der Merwe     2
# 124  RE van der Merwe     1
# 128  RE van der Merwe     1
# 129  RE van der Merwe     4
# 130  RE van der Merwe     6

# %%
df_Merwe
# Out:
#    Over  Runs
# 0  12.0     5
# 1  14.0     2
# 2  16.0     5
# 3  18.0     4
# 4  20.0     5
# 5  22.0     5
# 6  31.0     1
# 7  33.0     2
# 8  40.0     3
# 9  42.0    11

# %%
Merwe_final=pd.merge(RE_van_der_Merwe,df_Merwe,on='Runs')

# %%
df1['Bowler'].unique()
# Out:
# array(['DW Steyn', 'WD Parnell', 'RE van der Merwe', 'CK Langeveldt',
#        'JP Duminy', 'JH Kallis'], dtype=object)

# %%
WD_Parnell
# Out:
#     Bowler_name  Run_type
# 4    WD Parnell         4
# 5    WD Parnell         4
# 6    WD Parnell         0
# 7    WD Parnell         2
# 10   WD Parnell         0
# 11   WD Parnell         1
# 23   WD Parnell         2
# 24   WD Parnell         4
# 25   WD Parnell         2
# 26   WD Parnell         1
# 28   WD Parnell         4
# 29   WD Parnell         1
# 30   WD Parnell         0
# 31   WD Parnell         4
# 110  WD Parnell         1
# 111  WD Parnell         1
# 112  WD Parnell         4
# 113  WD Parnell         0
# 117  WD Parnell         4
# 118  WD Parnell         1
# 134  WD Parnell         1
# 138  WD Parnell         2
# 139  WD Parnell         2
# 140  WD Parnell         1

# %%
df_WD_Parnell
# Out:
#    Over  Runs
# 0   2.0    10
# 1   4.0     1
# 2   8.0     9
# 3  10.0     9
# 4  36.0     6
# 5  38.0     5
# 6  44.0     1
# 7  46.0     5

# %%
WD_Parnell.rename(columns = {'Run_type':'Runs'}, inplace = True)
RE_van_der_Merwe.rename(columns = {'Run_type':'Runs'}, inplace = True)
CK_Langeveldt.rename(columns = {'Run_type':'Runs'}, inplace = True)
JP_Duminy.rename(columns = {'Run_type':'Runs'}, inplace = True)
JH_Kallis.rename(columns = {'Run_type':'Runs'}, inplace = True)

# %%
WD_Parnell_final=pd.merge(WD_Parnell,df_WD_Parnell,on='Runs')
Merwe_final=pd.merge(RE_van_der_Merwe,df_Merwe,on='Runs')
CK_Langeveldt_final=pd.merge(CK_Langeveldt,df_Langeveldt,on='Runs')
JP_Duminy_final=pd.merge(JP_Duminy,df_JP_Duminy,on='Runs')
JH_Kallis_final=pd.merge(JH_Kallis,df_JH_Kallis,on='Runs')

# %%
fig=plt.figure(figsize=(25,12))


plt.subplot(2,6,1)
plot1=sns.barplot(x=df_steyn['Over'],y=df_steyn['Runs'])
plot1.set_title('Steyn')

plt.subplot(2,6,2)
plot2=sns.barplot(x=df_Merwe['Over'],y=df_Merwe['Runs'])
plot2.set_title('Merwe')  

plt.subplot(2,6,3)
plot3=sns.barplot(x=df_WD_Parnell['Over'],y=df_WD_Parnell['Runs'])
plot3.set_title('WD_Parnell')

plt.subplot(2,6,4)
plot4= sns.barplot(x=df_Langeveldt['Over'],y=df_Langeveldt['Runs'])
plot4.set_title('Langeveldt')

plt.subplot(2,6,5)
plot5=sns.barplot(x=df_JP_Duminy['Over'],y=df_JP_Duminy['Runs'])
plot5.set_title('JP_Duminy')

plt.subplot(2,6,6)
plot6=sns.barplot(x=df_JH_Kallis['Over'],y=df_Langeveldt['Runs'])
plot6.set_title('JH_Kallis')
# Out:
# Text(0.5, 1.0, 'JH_Kallis')

# %%
df3['Bowler'].unique()
# Out:
# array(['MA Wood', 'CR Woakes', 'AU Rashid', 'TK Curran', 'BA Stokes',
#        'MM Ali'], dtype=object)

# %%
fig=plt.figure(figsize=(25,12))


plt.subplot(2,6,1)
plot1=sns.barplot(x=df_MA_Wood['Over'],y=df_MA_Wood['Runs'])
plot1.set_title('MA Wood')

plt.subplot(2,6,2)
plot2=sns.barplot(x=df_CR_Woakes['Over'],y=df_CR_Woakes['Runs'])
plot2.set_title('CR Woakes')  

plt.subplot(2,6,3)
plot3=sns.barplot(x=df_AU_Rashid['Over'],y=df_AU_Rashid['Runs'])
plot3.set_title('AU Rashid')

plt.subplot(2,6,4)
plot4= sns.barplot(x=df_TK_Curran['Over'],y=df_TK_Curran['Runs'])
plot4.set_title('TK Curran')

plt.subplot(2,6,5)
plot5=sns.barplot(x=df_BA_Stokes['Over'],y=df_BA_Stokes['Runs'])
plot5.set_title('JP_Duminy')

plt.subplot(2,6,6)
plot6=sns.barplot(x=df_MM_Ali['Over'],y=df_MM_Ali['Runs'])
plot6.set_title('MM Ali')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [260], in <cell line: 28>()
#      25 plot6=sns.barplot(x=df_MM_Ali['Over'],y=df_MM_Ali['Runs'])
#      26 plot6.set_title('MM Ali')
# ---> 28 plt.imsave('Taylor_every_over',arr)
#
# NameError: name 'arr' is not defined
